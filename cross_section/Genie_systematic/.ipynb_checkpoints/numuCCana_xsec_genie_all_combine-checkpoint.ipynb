# %%
from __future__ import division
import imp
import uproot
import matplotlib
#matplotlib.use('agg')
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import pandas as pd
import os
import ROOT
import time
import math
import collections
from array import array

inputdir = '/home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/'
outputdir = inputdir+'xsec_all_combine/' 
output_filedir = outputdir
input_filedir = '/home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/'
lib_function_dir = '/home/tmettler/Desktop/uBoone/do_plots/'

# helper functions
globale = imp.load_source('globale',lib_function_dir+'globale.py')
NuCC = imp.load_source('NuCC_function',lib_function_dir+'NuCC_function.py')
NuCC_w = imp.load_source('NuCCWeight_function',lib_function_dir+'NuCCWeight_function.py')
# Out:
# Welcome to JupyROOT 6.10/08

# %%
pot_data = 8.649e+18

# %%
#!jupyter nbconvert --to script numuCCana_muon_cut_weight.ipynb

# %%
# initialte ROOT default canvas
ROOT.gStyle.SetOptStat(0)
c1 = ROOT.TCanvas("c1","c1",1600,1200)
c1.SetGrid(1)
c1.SetLeftMargin(0.14)
c1.SetRightMargin(0.18)
c1.SetBottomMargin(0.14)
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1

# %% [markdown]
# # All Genie cross section variation 100 multisims, mitigation cos(Theta)

# %%
##### flux and number of tragets parameters###
flux = 1.16859e11/1.592e20 # flux per POT per cm2
roh_data = 1.3836 #data denisity g/cm3
roh_MC = 1.3954 # MC denisity g/cm3
mol = 39.95 # g for argon
N_A = 6.022140857e23 # molec/mol avogadro zahl
N_nucleons = 40.0
V_fid = ((254.8-10)-(-1.55+10))*((117.47-10)-(-115.53+10))*((1036.9-50)-(-0.1+10))
print 'Fiducial Volume: ', V_fid
##############################################

beam_flux = flux * pot_data
print 'Beam flux = {:.5e}'.format(beam_flux),' /cm2'
N_tot = roh_data*N_A*N_nucleons*V_fid/mol
print 'Number of target nuclei= {:.5e}'.format(N_tot),' /cm3'
# Out:
# Fiducial Volume:  49184671.35
# Beam flux = 6.34870e+09  /cm2
# Number of target nuclei= 4.10331e+31  /cm3

# %%
# initialte ROOT default canvas
ROOT.gStyle.SetOptStat(0)
c1 = ROOT.TCanvas("c1","c1",1600,1200)
c1.SetGrid(1)
c1.SetLeftMargin(0.14)
c1.SetRightMargin(0.18)
c1.SetBottomMargin(0.14)
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1

# %%
path = '/home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/'
f_mom_tmp = ROOT.TFile.Open(path+"xsec_all_genie/All_Genie.root", 'read')
f_mom = ROOT.TFile.Open(path+"xsec_all_genie/All_Genie_save.root", 'read')
# Out:
# Warning in <TFile::Init>: file /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root probably not closed, trying to recover
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_1d[0] at address 370
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_1d_true[0] at address 823
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_1d[1] at address 1286
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_1d_true[1] at address 1743
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_1d[2] at address 2206
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_1d_true[2] at address 2663
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_1d[3] at address 3127
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_1d_true[3] at address 3583
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_1d[4] at address 4047
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_1d_true[4] at address 4502
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_1d[5] at address 4965
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_1d_true[5] at address 5421
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_1d[6] at address 5884
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_1d_true[6] at address 6340
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_1d[7] at address 6805
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_1d_true[7] at address 7261
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_1d[8] at address 7724
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_1d_true[8] at address 8180
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_1d[9] at address 8642
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_1d_true[9] at address 9094
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_1d[10] at address 9559
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_1d_true[10] at address 10017
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_1d[11] at address 10483
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_1d_true[11] at address 10941
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_1d
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_true[16] at address 314796
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_tilde[17] at address 315260
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_true[17] at address 315738
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_tilde[18] at address 316200
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_true[18] at address 316678
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_tilde[19] at address 317141
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_true[19] at address 317620
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_tilde[20] at address 318084
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_true[20] at address 318562
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_tilde[21] at address 319026
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_true[21] at address 319504
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_tilde[22] at address 319967
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_true[22] at address 320445
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_tilde[23] at address 320908
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_true[23] at address 321386
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_tilde[24] at address 321850
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_true[24] at address 322327
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_tilde[25] at address 322790
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_true[25] at address 323269
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_tilde[26] at address 323733
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_true[26] at address 324211
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_tilde[27] at address 324674
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_true[27] at address 325152
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_tilde[28] at address 325615
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_true[28] at address 326093
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_tilde[29] at address 326557
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_true[29] at address 327035
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_tilde[30] at address 327499
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_true[30] at address 327976
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_tilde[31] at address 328440
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_true[31] at address 328918
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_tilde[32] at address 329381
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_true[32] at address 329859
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_tilde[33] at address 330323
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_true[33] at address 330801
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_tilde[34] at address 331265
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_true[34] at address 331743
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_tilde[35] at address 332207
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_true[35] at address 332685
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_tilde[36] at address 333148
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_true[36] at address 333628
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_tilde[37] at address 334092
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_true[37] at address 334570
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_tilde[38] at address 335033
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_true[38] at address 335510
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_tilde[39] at address 335973
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_true[39] at address 336450
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_tilde[40] at address 336914
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_true[40] at address 337392
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_tilde[41] at address 337856
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_true[41] at address 338334
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_tilde[42] at address 338797
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_true[42] at address 339275
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_tilde[43] at address 339738
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_true[43] at address 340216
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_tilde[44] at address 340680
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_true[44] at address 341157
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_tilde[45] at address 341620
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_true[45] at address 342098
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_tilde[46] at address 342561
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_true[46] at address 343039
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_tilde[47] at address 343503
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_true[47] at address 343980
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_tilde[48] at address 344443
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_true[48] at address 344921
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_tilde[49] at address 345385
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_true[49] at address 345863
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_tilde[50] at address 346327
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_true[50] at address 346805
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_tilde[51] at address 347267
# Info in <TFile::Recover>: /home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/weighted/xsec_all_genie/All_Genie_save.root, recovered key TH1F:h_eff_true[51] at address 347745
# Warning in <TFile::Init>: successfully recovered 604 keys

# %%
mom_bins = [ 0.00, 0.18, 0.30, 0.45, 0.77, 1.28, 2.50 ]
binnum = len(mom_bins) - 1
num_universes = 100

# %%
h_data = f_mom_tmp.Get('h_data_mom')
h_ext = f_mom_tmp.Get('h_ext_mom')
h_dirt = f_mom_tmp.Get('h_dirt_mom')

print h_data.Integral(0,binnum+1)
print h_ext.Integral(0,binnum+1)
print h_dirt.Integral(0,binnum+1)
# Out:
# 1470.0
# 161.40625117
# 36.0061702952

# %%
#del h_bkg[:]
#del h_sig[:]
#del h_true[:]
#del h_mitigation_matrix[:]

# %%
h_bkg = []
h_sig = []
h_true = []
h_mitigation_matrix = []
i = 0
legend = ROOT.TLegend(0.65,0.55,0.9,0.9); #LEGEND RIGHT
for uni in range(num_universes):
    h_bkg.append(f_mom.Get('h_1d_bkg['+str(uni)+']'))
    h_sig.append(f_mom.Get('h_1d['+str(uni)+']'))
    h_true.append(f_mom.Get('h_1d_true['+str(uni)+']'))
    h_mitigation_matrix.append(f_mom.Get('h_mitigation_matrix['+str(uni)+']'))

# %%
print h_sig[99].Integral(0,binnum+1),h_true[99].Integral(0,binnum+1)
#h_mitigation_matrix[50].Draw('colz text')
#c1.Draw()
# Out:
# 193201.051758 392357.88623

# %%
mitigation_matrix = np.zeros((num_universes,7,6))
for uni in range(num_universes):
    for j in range(1,binnum+1):
        for i in range(1,binnum+2):
            mitigation_matrix[uni,i-1,j-1]= h_mitigation_matrix[uni].GetBinContent(i,j)

# %%
# calculate e tilde for all universes
N_sel = np.zeros((num_universes,6))
N_gen = np.zeros((num_universes,6))
eff_tilde = np.zeros((num_universes,7))
for uni in range(num_universes):
    for i in range(1,binnum+1):
        N_sel[uni][i-1] = h_sig[uni].GetBinContent(i)
        N_gen[uni][i-1] = h_true[uni].GetBinContent(i)
    eff_tilde[uni] = mitigation_matrix[uni].dot(N_sel[uni])/(mitigation_matrix[uni].dot(N_gen[uni]))

# %%
print eff_tilde[99]
#del h_eff_true[:]
#del h_eff_tilde[:]
# Out:
# [0.19733914 0.34012176 0.43894242 0.51848524 0.59917517 0.62824054
#  0.58151965]

# %%
#h_eff_tilde[99].Draw()
#c1.Draw()

# %%
h_eff_true = {}
h_eff_tilde = {}
for uni in range(num_universes):
    h_eff_tilde[uni] = ROOT.TH1F("h_eff_tilde["+str(uni)+']','Efficiency tilde',binnum,array('f',mom_bins))
    h_eff_true[uni] = h_sig[uni].Clone()
    h_eff_true[uni].Sumw2()
    h_eff_true[uni].Divide(h_true[uni])
    for i in range(1,binnum+1):
        h_eff_tilde[uni].SetBinContent(i,eff_tilde[uni][i-1])
        h_eff_tilde[uni].SetBinError(i,h_eff_true[uni].GetBinError(i))
    h_eff_tilde[uni].SetYTitle("reconstructed efficiency")
    h_eff_tilde[uni].SetXTitle("p_{\mu} \quad [GeV]")
# Out:
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created

# %%
h_xsec = {}
for uni in range(num_universes): 
    h_xsec[uni] = h_data.Clone()
    h_xsec[uni].Sumw2()
    h_xsec[uni].Add(h_ext,-1)
    h_xsec[uni].Add(h_dirt,-1)
    h_xsec[uni].Add(h_bkg[uni],-1)
    #print h_xsec[uni].GetSumOfWeights()
# Out:
# 1009.80438614
# 1033.9414978
# 1034.70359612
# 1029.68496609
# 1049.95366192
# 1081.55663967
# 1046.34973145
# 1076.55352783
# 1070.84692383
# 958.981908798
# 1041.87957573
# 997.09038353
# 995.949331284
# 987.460596085
# 965.719135284
# 1001.94078445
# 993.259143829
# 1057.26563358
# 1052.76981068
# 1022.02940941
# 1062.51675797
# 1005.17437172
# 1096.77787781
# 1079.02937317
# 975.081504822
# 1017.61198807
# 1057.64934921
# 1021.01472282
# 999.489318848
# 1007.00174141
# 1029.87435913
# 973.267908096
# 1021.06908798
# 1064.92664433
# 1009.53977585
# 1041.14562321
# 1045.05933666
# 1062.39033508
# 1015.00935364
# 1037.02867794
# 1024.78332901
# 1035.91503143
# 992.525798798
# 1062.11419773
# 1064.8432827
# 1041.34902191
# 1027.144701
# 1089.4907465
# 991.228450775
# 1031.15737152
# 1043.04516125
# 998.367660522
# 1059.8901062
# 1059.56816006
# 1058.56429195
# 1027.49976921
# 1023.60959435
# 1016.00024033
# 1042.2357893
# 945.676527023
# 1011.37348175
# 1087.02538109
# 1036.21817493
# 952.762952805
# 1012.90833092
# 1025.94464111
# 1009.17462921
# 977.676671982
# 1015.5234642
# 1038.37401104
# 1055.75873089
# 995.407726288
# 1017.9974556
# 986.967609406
# 1065.4306097
# 1014.55513191
# 1045.12874031
# 1057.3164835
# 1048.85789013
# 1079.81458855
# 1055.29624271
# 991.130414963
# 1054.65057468
# 1056.9246645
# 958.700994492
# 1038.69384193
# 982.64563942
# 1026.76167202
# 1123.43591881
# 973.871864319
# 1059.56280613
# 971.770679474
# 974.154693604
# 1042.75643539
# 1056.17897034
# 942.990385056
# 1076.12189102
# 1064.69728851
# 1066.32913303
# 1006.13137817
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created

# %%
for uni in range(num_universes): 
    h_xsec[uni].Divide(h_eff_tilde[uni])
    h_xsec[uni].Scale(1.0/(N_tot * beam_flux))
    for i in range(1,binnum+1):
        h_xsec[uni].SetBinContent(i,h_xsec[uni].GetBinContent(i)/h_xsec[uni].GetBinWidth(i))
        h_xsec[uni].SetBinError(i,h_xsec[uni].GetBinError(i)/h_xsec[uni].GetBinWidth(i))

    #h_xsec[uni].Write('h_xsec['+str(uni)+']')

# %%
for i in range(num_universes): 
    h_xsec[i].Scale(1e38)

# %%
path_cv = '/home/tmettler/Desktop/ub_data/mcc9.1/v08_00_00_33/V08_00_00_35/weighted/xsec_filesV4/'
f_cv = ROOT.TFile.Open(path_cv+"xsec_momentum_wighted.root", 'read')

h_xsec_cv = f_cv.Get('h_xsec_data')

# %%
h_xsec_cv.Draw('hist')
for uni in range(num_universes): 
    h_xsec[uni].SetMaximum(1.6)
    h_xsec[uni].SetLineColorAlpha(ROOT.kRed,0.6)
    h_xsec[uni].SetYTitle("d\sigma / d p_{\mu} \quad [10^{-38} cm^2/GeV]")
    h_xsec[uni].SetXTitle("p_{\mu} [GeV]")
    h_xsec[uni].Draw('hist same')
h_xsec_cv.Draw('hist same')   
c1.Draw()

# %%
num_bins = h_xsec[0].GetNbinsX()

xsec_cov_matrix = np.zeros((num_bins,num_bins))
xsec_frac_cov_matrix = np.zeros((num_bins,num_bins))
#xsec_diff_matrix = np.zeros((num_bins))
for uni in range(num_universes):
    xsec_diff_matrix = np.zeros((num_bins))
    for b in range(num_bins):
        xsec_diff_matrix[b]= (h_xsec_cv.GetBinContent(b+1)-h_xsec[uni].GetBinContent(b+1) )
    #print np.matmul(xsec_diff_matrix,np.transpose(xsec_diff_matrix))
    xsec_cov_matrix = xsec_cov_matrix + xsec_diff_matrix.reshape(num_bins,1) * xsec_diff_matrix
xsec_cov_matrix = xsec_cov_matrix/num_universes
    
xsec_corr_matrix = np.zeros((num_bins,num_bins))
for i in range(num_bins): 
    for j in range(num_bins):
        xsec_corr_matrix[i][j] = xsec_cov_matrix[i][j]/(math.sqrt(xsec_cov_matrix[i][i]*xsec_cov_matrix[j][j]))
        xsec_frac_cov_matrix[i][j] = xsec_cov_matrix[i][j]/(h_xsec_cv.GetBinContent(i+1)*h_xsec_cv.GetBinContent(j+1))
#np.save(output_filedir+'correlation_detsys',xsec_corr_matrix)
#np.save(output_filedir+'covariance_detsys',xsec_cov_matrix)

# %%
ROOT.gStyle.SetPaintTextFormat('0.3f')
h_correlation = ROOT.TH2D("h_correlation",'Correlation matrix',6,0,6,6,0,6)
for i in range(num_bins):
    for j in range(num_bins):
        h_correlation.SetBinContent(i+1,j+1,xsec_corr_matrix[i,j])
#h_covariance.SetXTitle("Reco bin i, 7=overflow")
#h_covariance.SetYTitle("True bin j")
h_correlation.SetXTitle("Reco bin i")
h_correlation.SetYTitle("Reco bin j")
#h_correlation.SetMinimum(-1)
h_correlation.Draw('colz')
h_correlation.Draw('same text')
c1.Draw()
c1.SaveAs(outputdir_png + "h_correlation_detsys.png")
c1.SaveAs(outputdir_root + "h_correlation_detsys.root")
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-46-2b123bca3245> in <module>()
#      12 h_correlation.Draw('same text')
#      13 c1.Draw()
# ---> 14 c1.SaveAs(outputdir_png + "h_correlation_detsys.png")
#      15 c1.SaveAs(outputdir_root + "h_correlation_detsys.root")
#
# NameError: name 'outputdir_png' is not defined
# Warning in <TFile::Append>: Replacing existing TH1: h_correlation (Potential memory leak).

# %%
ROOT.gStyle.SetPaintTextFormat('0.6g')
h_covariance = ROOT.TH2D("h_covariance",'Covariance matrix',6,0,6,6,0,6)
for i in range(num_bins):
    for j in range(num_bins):
        h_covariance.SetBinContent(i+1,j+1,xsec_cov_matrix[i,j]*1e-76)
#h_covariance.SetXTitle("Reco bin i, 7=overflow")
#h_covariance.SetYTitle("True bin j")
h_covariance.SetXTitle("Reco bin i")
h_covariance.SetYTitle("Reco bin j")
h_covariance.Draw('colz')
h_covariance.Draw('same text')
c1.Draw()
c1.SaveAs(outputdir_png + "h_covariance_detsys.png")
c1.SaveAs(outputdir_root + "h_covariance_detsys.root")
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-47-a6c9ebc555dc> in <module>()
#      11 h_covariance.Draw('same text')
#      12 c1.Draw()
# ---> 13 c1.SaveAs(outputdir_png + "h_covariance_detsys.png")
#      14 c1.SaveAs(outputdir_root + "h_covariance_detsys.root")
#
# NameError: name 'outputdir_png' is not defined
# Warning in <TFile::Append>: Replacing existing TH1: h_covariance (Potential memory leak).

# %%
ROOT.gStyle.SetPaintTextFormat('0.6f')
h_frac_covariance = ROOT.TH2F("h_frac_covariance",'fractional covariance matrix',6,0,6,6,0,6)
for i in range(num_bins):
    for j in range(num_bins):
        h_frac_covariance.SetBinContent(i+1,j+1,xsec_frac_cov_matrix[i,j])
h_frac_covariance.SetXTitle("Reco bin i")
h_frac_covariance.SetYTitle("Reco bin j")
h_frac_covariance.Draw('colz')
c1.SetLogz(0)
h_frac_covariance.Draw('same text')
c1.Draw()
c1.SaveAs(outputdir_png + "h_frac_covariance_detsys.png")
c1.SaveAs(outputdir_root + "h_frac_covariance_detsys.root")
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-49-cb7df875eebd> in <module>()
#      10 h_frac_covariance.Draw('same text')
#      11 c1.Draw()
# ---> 12 c1.SaveAs(outputdir_png + "h_frac_covariance_detsys.png")
#      13 c1.SaveAs(outputdir_root + "h_frac_covariance_detsys.root")
#
# NameError: name 'outputdir_png' is not defined

# %%
#with stat error
h_xsec_cv.Draw('hist')
for uni in range(num_universes): 
    h_xsec[uni].SetMaximum(1.6)
    h_xsec[uni].SetLineColorAlpha(ROOT.kRed,0.6)
    h_xsec[uni].SetYTitle("d\sigma / d p_{\mu} \quad [10^{-38} cm^2/GeV]")
    h_xsec[uni].SetXTitle("p_{\mu} [GeV]")
    h_xsec[uni].Draw('hist same')
h_xsec_cv.Draw('hist E1 same')   
c1.Draw()

# %%
for i in range(num_bins):
    print math.sqrt(xsec_cov_matrix[i][i])
# Out:
# 0.0255698101611
# 0.0971052169066
# 0.0622541660499
# 0.0184317767316
# 0.00453554688313
# 0.000647666000075

# %%
#with sys error
h_xsec_cv.Draw('hist')
for uni in range(num_universes): 
    h_xsec[uni].SetMaximum(1.6)
    h_xsec[uni].SetLineColorAlpha(ROOT.kRed,0.6)
    h_xsec[uni].SetYTitle("d\sigma / d p_{\mu} \quad [10^{-38} cm^2/GeV]")
    h_xsec[uni].SetXTitle("p_{\mu} [GeV]")
    h_xsec[uni].Draw('hist same')
for i in range(num_bins):
    h_xsec_cv.SetBinError(i,math.sqrt(xsec_cov_matrix[i][i]))
h_xsec_cv.Draw('hist E1 same')   
c1.Draw()

# %%
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-53-0efefad1bd99> in <module>()
#      11 h_covariance.Draw('same text')
#      12 c1.Draw()
# ---> 13 c1.SaveAs(outputdir_png + "h_covariance_detsys.png")
#      14 c1.SaveAs(outputdir_root + "h_covariance_detsys.root")
#
# NameError: name 'outputdir_png' is not defined
# Warning in <TFile::Append>: Replacing existing TH1: h_covariance (Potential memory leak).

# %%
weight_name = 'EventWeight*TunedCentralValue_Genie'
num_universes = 100
eff_uni = np.zeros((num_universes))
mom_bins = [ -1.00, -0.50, 0.00, 0.28, 0.47, 0.63, 0.765, 0.865, 0.935, 1.00 ]
binnum = len(mom_bins) - 1

# %%
# close the root file with all the histos
RootFile.Close()
