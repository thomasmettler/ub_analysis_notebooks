# %%
import uproot
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sys
import os
sys.path.insert(0, "/home/tmettler/Software/root_v6.10.08/Install/lib/ROOT.py")
#sys.path.append('/home/tmettler/Software/root_v6.10.08/Install/lib/ROOT.pyc')
import ROOT
# Out:
# Welcome to JupyROOT 6.10/08

# %%
print(ROOT.__file__)
import sys
sys.path
# Out:
# /home/tmettler/Software/root_v6.10.08/Install/lib/ROOT.pyc
# ['/home/tmettler/Software/root_v6.10.08/Install/lib/ROOT.py',
#  '',
#  '/usr/local/lib/python2.7/dist-packages/python_telegram_bot-10.1.0-py2.7.egg',
#  '/usr/local/lib/python2.7/dist-packages/certifi-2018.4.16-py2.7.egg',
#  '/usr/local/lib/python2.7/dist-packages/future-0.16.0-py2.7.egg',
#  '/usr/local/lib/python2.7/dist-packages/Keras-2.2.4-py2.7.egg',
#  '/usr/local/lib/python2.7/dist-packages/pip-19.1.1-py2.7.egg',
#  '/home/tmettler/Software/root_v6.10.08/Install/lib',
#  '/usr/lib/python2.7',
#  '/usr/lib/python2.7/plat-x86_64-linux-gnu',
#  '/usr/lib/python2.7/lib-tk',
#  '/usr/lib/python2.7/lib-old',
#  '/usr/lib/python2.7/lib-dynload',
#  '/home/tmettler/.local/lib/python2.7/site-packages',
#  '/usr/local/lib/python2.7/dist-packages',
#  '/usr/lib/python2.7/dist-packages',
#  '/usr/lib/python2.7/dist-packages/PILcompat',
#  '/usr/lib/python2.7/dist-packages/gtk-2.0',
#  '/usr/lib/python2.7/dist-packages/ubuntu-sso-client',
#  '/home/tmettler/.local/lib/python2.7/site-packages/IPython/extensions',
#  '/home/tmettler/.ipython']

# %% [markdown]
# # CRTinBNB tagger, Overlay or MC

# %%
#file = uproot.open( inputdir + 'NeutSlices_QP_allExt_withVertex.root_ana.root')
#file.keys("a")

# %%
#slices = file['t_slice']
#print 'Number of entries: ', slices.numentries
#slices.keys()

# %%
inputdir = '/home/tmettler/Desktop/ub_data/mcc9.1/CRTinBNB/'
outputdir = '/home/tmettler/Desktop/ub_data/mcc9.1/CRTinBNB/overlay_10k_plots/'
try:
    os.stat(outputdir)
except:
    os.mkdir(outputdir)
#filename = 'NeutrinoCRTMatcher_QP_MC_BNB_10k.root'
#filename = 'NeutrinoCRTMatcher_QP_Overlay_bigWindow.root'
#filename = 'NeutrinoCRTMatcher_QP_6500_bigWindow.root'
filename = 'NeutrinoCRTProducer_20190723T144641_QP.root'

isMC = 1
useT1 = 0

# %%
test = ROOT.TChain("bnbcrttag/my_event","my_event")
test.Add( inputdir + filename)

#test.ls()
print "Number of Entries:", test.GetEntries()
# uncomment one of them
cutname = 'has_nuslice'

cut = ' && ' + cutname
#cut = ''

title_cut = ''
if(cut!=''):
    title_cut = ' with '+ cutname
# BNB: 3.195 - 4.875 // Ext: 3.570 - 5.250
# Out:
# Number of Entries: 10000
# Warning in <TClass::Init>: no dictionary for class ROOT::TIOFeatures is available

# %%
ROOT.gStyle.SetOptStat(0)
c1 = ROOT.TCanvas("","",1600,1200)
c1.SetGrid(1)
c1.SetLeftMargin(0.14)
c1.SetRightMargin(0.18)
c1.SetBottomMargin(0.14)
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name:

# %%
if(isMC==0):
    h_bnbtime = ROOT.TH1F("h_bnbtime","BNB signal time" + title_cut,100,0,10)
    h_bnbtime1 = ROOT.TH1F("h_bnbtime1","CRT ts0",100,0,10)
    h_bnbtime2 = ROOT.TH1F("h_bnbtime2","CRT ts0",100,0,10)
    h_bnbtime3 = ROOT.TH1F("h_bnbtime3","CRT ts0",100,0,10)
    #ROOT.gStyle.SetLineWidth(5);
    test.Draw('flash_time>>h_bnbtime','1' + cut)
    test.Draw('crthit_ts0+(crt_trig_corr_med-69100)/1000>>h_bnbtime1','has_crthit' + cut)
    test.Draw('crthit_ts0>>h_bnbtime3','has_crthit' + cut)
    #test.Draw('crtt0_time>>h_bnbtime3','has_crtasso' + cut)
    h_bnbtime1.SetLineColorAlpha(2, 1)
    h_bnbtime1.SetLineWidth(4);
    h_bnbtime3.SetLineColorAlpha(4, 1)
    h_bnbtime3.SetLineWidth(4);
    h_bnbtime.SetLineWidth(4);
    h_bnbtime.SetXTitle("Signal time [us]")
    h_bnbtime.SetYTitle("Entries per bin")
    
    if(useT1==1):
        test.Draw('crthit_ts1>>h_bnbtime2','has_crthit' + cut)
        h_bnbtime2.SetLineColorAlpha(3, 1)

    legend = ROOT.TLegend(0.15,0.75,0.48,0.9)
    #legend = ROOT.TLegend(0.5, 0.5, 0.75, 0.75)
    legend.AddEntry(h_bnbtime,"flash time","l")
    legend.AddEntry(h_bnbtime1,"CRT hit time","l")
    #legend.AddEntry(h_bnbtime2,"CRT hit time MC","l");
    legend.AddEntry(h_bnbtime3,"CRT uncorr","l");
    #h_x.SetStats(1);
    h_bnbtime.Draw();
    h_bnbtime1.Draw("same");
    if(useT1==1):
        h_bnbtime2.Draw("same");
        legend.AddEntry(h_bnbtime2,"CRT hit time ts1","l")
    h_bnbtime3.Draw("same");
    legend.Draw();
    h_bnbtime.Draw("same");

    c1.Draw()
    c1.SaveAs(outputdir + "h_bnbtime.png");

# %%
# generate Vertex x position plot
# BNB: 3.195 - 4.875 // Ext: 3.570 - 5.250
if(isMC==1):
    ROOT.gStyle.SetOptStat(1)
    h_bnbtime = ROOT.TH1F("h_bnbtime","BNB signal time",100,2,6)
    h_bnbtime1 = ROOT.TH1F("h_bnbtime1","CRT ts0",100,2,6)
    h_bnbtime2 = ROOT.TH1F("h_bnbtime2","CRT ts0",100,2,6)
    h_bnbtime3 = ROOT.TH1F("h_bnbtime3","CRT ts0",100,2,6)

    test.Draw('flash_time>>h_bnbtime','1' + cut)
    test.Draw('crthit_ts0+(crt_trig_corr_med)/1000>>h_bnbtime1','has_crthit && adc_length==32' + cut)
    test.Draw('crthit_ts0+(69457-69000)/1000>>h_bnbtime2','has_crthit && adc_length<32' + cut)
    test.Draw('crtt0_time+(69457-69000)/1000>>h_bnbtime3','has_crtasso' + cut)
    h_bnbtime1.SetLineColorAlpha(2, 1);
    h_bnbtime2.SetLineColorAlpha(3, 1);
    h_bnbtime3.SetLineColorAlpha(4, 1);
    h_bnbtime.SetXTitle("Signal time [us]");
    h_bnbtime.SetYTitle("Entries per bin");

    legend = ROOT.TLegend(0.15,0.75,0.48,0.9);
    #legend = ROOT.TLegend(0.5, 0.5, 0.75, 0.75)
    legend.AddEntry(h_bnbtime,"flash time","l");
    legend.AddEntry(h_bnbtime1,"ext CRT hit time","l");
    legend.AddEntry(h_bnbtime2,"MC CRT hit time","l");
    legend.AddEntry(h_bnbtime3,"CRT asso time","l");
    
    h_bnbtime.SetLineWidth(4);
    h_bnbtime1.SetLineWidth(4);
    h_bnbtime2.SetLineWidth(4);
    h_bnbtime3.SetLineWidth(4);
    #h_x.SetStats(1);
    h_bnbtime.Draw();
    h_bnbtime1.Draw("same");
    h_bnbtime2.Draw("same");
    h_bnbtime3.Draw("same");
    legend.Draw();
    h_bnbtime.Draw("same");

    c1.Draw()
    c1.SaveAs(outputdir + "h_bnbtime.png");
    
    test.Draw('crthit_ts0>>h_bnbtime2','has_crthit && adc_length<32' + cut)
    test.Draw('crtt0_time>>h_bnbtime3','has_crtasso' + cut)
    
    h_bnbtime.Draw();
    h_bnbtime1.Draw("same");
    h_bnbtime2.Draw("same");
    h_bnbtime3.Draw("same");
    legend.Draw();
    h_bnbtime.Draw("same");

    c1.Draw()
    c1.SaveAs(outputdir + "h_bnbtime_uncorr.png");
# Out:
# Warning in <TROOT::Append>: Replacing existing TH1: h_bnbtime (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h_bnbtime1 (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h_bnbtime2 (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h_bnbtime3 (Potential memory leak).
# Info in <TCanvas::Print>: png file /home/tmettler/Desktop/ub_data/mcc9.1/CRTinBNB/overlay_10k_plots/h_bnbtime.png has been created
# Info in <TCanvas::Print>: png file /home/tmettler/Desktop/ub_data/mcc9.1/CRTinBNB/overlay_10k_plots/h_bnbtime_uncorr.png has been created

# %%
# generate number of BNB CRT hits plot
if(isMC==1):
    start = 0
    end = 10
    binx = 10
    h_nrCrthit = ROOT.TH1F("h_nrCrthit","CRT signal time" + title_cut,binx,start,end)
    h_nrCrthit1 = ROOT.TH1F("h_nrCrthit1","CRT ts0",binx,start,end)
    h_nrCrthit2 = ROOT.TH1F("h_nrCrthit2","CRT ts0",binx,start,end)

    test.Draw('nr_crthit>>h_nrCrthit','1' + cut)
    test.Draw('nr_crthit>>h_nrCrthit1','has_crthit && adc_length==32' + cut)
    test.Draw('nr_crthit>>h_nrCrthit2','has_crthit && adc_length<32' + cut)
    h_nrCrthit1.SetLineColorAlpha(2, 1);
    h_nrCrthit2.SetLineColorAlpha(3, 1);
    h_nrCrthit.SetXTitle("Signal time [us]");
    h_nrCrthit.SetYTitle("Entries per bin");

    legend = ROOT.TLegend(0.15,0.75,0.48,0.9);
    #legend = ROOT.TLegend(0.5, 0.5, 0.75, 0.75)
    legend.AddEntry(h_nrCrthit,"All CRT hit time","l");
    legend.AddEntry(h_nrCrthit1,"EXT","l");
    legend.AddEntry(h_nrCrthit2,"MC","l");
    h_nrCrthit.SetLineWidth(4);
    h_nrCrthit1.SetLineWidth(4);
    h_nrCrthit2.SetLineWidth(4);
    #h_x.SetStats(1);
    h_nrCrthit.Draw("");
    h_nrCrthit1.Draw("same");
    #h_nrCrthit2.Draw("same TEXT0 E");
    h_nrCrthit2.Draw("same");
    legend.Draw();
    h_nrCrthit.Draw("same");

    c1.Draw()
    c1.SaveAs(outputdir + "h_nrCrthit.png");
    print 'Number of Entries:', h_nrCrthit.Integral()
    print 'Number of Entries with EXT CRT hit:', h_nrCrthit1.Integral()
    print 'Number of Entries with MC CRT hit:', h_nrCrthit2.Integral()

    print 'Amount of Entries with EXT CRT hit:', h_nrCrthit1.Integral()*100/h_nrCrthit.Integral()
    print 'Amount of Entries with MC CRT hit:', h_nrCrthit2.Integral()*100/h_nrCrthit.Integral()
# Out:
# Number of Entries: 2767.0
# Number of Entries with EXT CRT hit: 102.0
# Number of Entries with MC CRT hit: 414.0
# Amount of Entries with EXT CRT hit: 3.68630285508
# Amount of Entries with MC CRT hit: 14.9620527647
# Warning in <TROOT::Append>: Replacing existing TH1: h_nrCrthit (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h_nrCrthit1 (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h_nrCrthit2 (Potential memory leak).
# Info in <TCanvas::Print>: png file /home/tmettler/Desktop/ub_data/mcc9.1/CRTinBNB/overlay_10k_plots/h_nrCrthit.png has been created

# %%
# generate number of BNB CRT hits plot
if(isMC==1):
    start_x = 68
    end_x  = 70
    h_flash_crt = ROOT.TH1F("h_flash_crt","Flash time - CRT time" + title_cut,500,start_x,end_x)
    h_flash_crt1 = ROOT.TH1F("h_flash_crt1","Flash time - CRT time [us]",500,start_x,end_x)


    test.Draw('flash_time - (crthit_ts0_uncorr-fTriTim_nsec)/1000>>h_flash_crt','has_flash  && adc_length==32' + cut)
    test.Draw('flash_time - (crthit_ts0_uncorr-fTriTim_nsec)/1000>>h_flash_crt1','has_flash && adc_length<32 && has_crthit' + cut)

    h_flash_crt1.SetLineColorAlpha(2, 1);
    h_flash_crt1.SetXTitle("Signal time [us]");
    h_flash_crt1.SetYTitle("Entries per bin");

    legend = ROOT.TLegend(0.15,0.75,0.48,0.9);
    #legend = ROOT.TLegend(0.5, 0.5, 0.75, 0.75)
    legend.AddEntry(h_flash_crt,"EXT","l");
    legend.AddEntry(h_flash_crt1,"MC","l");
    h_flash_crt.SetLineWidth(4);
    h_flash_crt1.SetLineWidth(4);
    #h_x.SetStats(1);
    legend.Draw();
    h_flash_crt1.Draw();
    h_flash_crt.Draw("same");
    legend.Draw();
    h_flash_crt1.Draw("same");

    c1.Draw()
    c1.SaveAs(outputdir + "h_flash_crt.png");
    rebinfactor = 2
    h_flash_crt_re = h_flash_crt.Rebin(rebinfactor)
    h_flash_crt_re.Scale(1.0/rebinfactor)
    h_flash_crt_re1 = h_flash_crt1.Rebin(rebinfactor)
    h_flash_crt_re1.Scale(1.0/rebinfactor)

    h_flash_crt_re1.Draw('HIST')
    h_flash_crt_re.Draw('HIST same')
    legend.Draw();
    c1.Draw()
    c1.SaveAs(outputdir + "h_flash_crt_re.png");
# Out:
# Warning in <TROOT::Append>: Replacing existing TH1: h_flash_crt (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h_flash_crt1 (Potential memory leak).
# Info in <TCanvas::Print>: png file /home/tmettler/Desktop/ub_data/mcc9.1/CRTinBNB/overlay_10k_plots/h_flash_crt.png has been created
# Info in <TCanvas::Print>: png file /home/tmettler/Desktop/ub_data/mcc9.1/CRTinBNB/overlay_10k_plots/h_flash_crt_re.png has been created

# %%
h_diff_crtt0_crt = ROOT.TH1F("h_diff_crtt0_crt","T0 time - CRT time" + title_cut,200,-2,2)

test.Draw('crtt0_time - crthit_ts0>>h_diff_crtt0_crt','has_crthit && has_crtasso' + cut)
h_diff_crtt0_crt.SetXTitle("time difference [us]");
h_diff_crtt0_crt.SetYTitle("Entries per bin");

legend = ROOT.TLegend(0.15,0.75,0.48,0.9);
#legend = ROOT.TLegend(0.5, 0.5, 0.75, 0.75)
legend.AddEntry(h_diff_crtt0_crt,"EXT","l");
#h_x.SetStats(1);
h_diff_crtt0_crt.Draw();
#legend.Draw();
h_diff_crtt0_crt.Draw("same");

c1.Draw()
c1.SaveAs(outputdir + "h_diff_crtt0_crt.png");
# Out:
# Warning in <TROOT::Append>: Replacing existing TH1: h_diff_crtt0_crt (Potential memory leak).
# Info in <TCanvas::Print>: png file /home/tmettler/Desktop/ub_data/mcc9.1/CRTinBNB/overlay_10k_plots/h_diff_crtt0_crt.png has been created

# %%
if(isMC==0):
    h_flash_crt = ROOT.TH1F("h_flash_crt","Flash time - CRT time" + title_cut,500,-5,5)
    h_flash_crt1 = ROOT.TH1F("h_flash_crt1","CRT ts0",500,-5,5)


    test.Draw('flash_time - crthit_ts0>>h_flash_crt','has_flash  && has_crthit' + cut)
    test.Draw('flash_time - (crthit_ts0+(crt_trig_corr_med-69100)/1000)>>h_flash_crt1','has_flash && has_crthit' + cut)

    h_flash_crt1.SetLineColorAlpha(2, 1);
    h_flash_crt.SetXTitle("Signal time [us]");
    h_flash_crt.SetYTitle("Entries per bin");

    #legend = ROOT.TLegend(0.15,0.75,0.48,0.9);
    #legend = ROOT.TLegend(0.5, 0.5, 0.75, 0.75)
    legend.AddEntry(h_flash_crt,"uncorr","l");
    legend.AddEntry(h_flash_crt1,"corr","l");
    #h_x.SetStats(1);
    h_flash_crt.Draw();
    h_flash_crt1.Draw("same");
    legend.Draw();
    h_flash_crt.Draw("same");

    c1.Draw()
    c1.SaveAs(outputdir + "h_flash_crt.png");
    rebinfactor = 2
    h_flash_crt_re = h_flash_crt.Rebin(rebinfactor)
    h_flash_crt_re.Scale(1.0/rebinfactor)
    #h_flash_crt_re1 = h_flash_crt1.Rebin(rebinfactor)
    #h_flash_crt_re1.Scale(1.0/rebinfactor)

    h_flash_crt_re.Draw('HIST')
    #h_flash_crt_re.Draw('HIST same')
    c1.Draw()
    c1.SaveAs(outputdir + "h_flash_crt_re.png");
