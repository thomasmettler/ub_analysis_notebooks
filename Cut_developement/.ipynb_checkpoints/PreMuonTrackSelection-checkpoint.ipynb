# %%
from __future__ import division
import imp
import uproot
import matplotlib
#matplotlib.use('agg')
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import pandas as pd
import os
import ROOT
import time
import math
helper = imp.load_source('helpfunction','/home/tmettler/Desktop/uBoone/do_plots/helpfunction.py')
#import /home/tmettler/Desktop/uBoone/do_plots/helpfunction as helper
import collections
NuCC = imp.load_source('NuCC_function','/home/tmettler/Desktop/uBoone/do_plots/NuCC_function.py')
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1

# %%
#get input file and output folder for plots
inputdir = '/home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/'
outputdir = '/home/tmettler/Desktop/v08_00_00_33/V08_00_00_35/pre_muon_selection/'
try:
    os.stat(outputdir)
except:
    os.mkdir(outputdir)

filename = 'NuCCana_overlay_V25.rootout33.root'

# %%
#file_tree = uproot.open(inputdir+filename)['numuCCAna/event']
file_tree = uproot.open(inputdir+filename)['t_out']
print 'length of event tree', file_tree.numentries
#print([c.decode('UTF-8') for c in file_tree.keys()])
# Out:
# length of event tree 1070522

# %%
cols = ['fEvtNum','frunNum','fsubRunNum','MCTrackPDG', 'MCTrackPurity', 'TrackPID_chiproton',\
        'TrackPID_chimuon','TrackPID_chipion','TrackLength','num_mc_muon','track_key','key_muon']
        
ev = file_tree.pandas.df(cols)

# %%
#tree_Event['has_muon'] = tree_Event['MCTrackPDG'].ne(13)
ev.head(10)
#tree_Event.index.names
# Out:
#                 fEvtNum  frunNum  fsubRunNum  MCTrackPDG  MCTrackPurity  \
# entry subentry
# 0     0             253    16265           5        13.0       0.960593
# 3     0             263    16265           5        13.0       0.978050
#       1             263    16265           5      2212.0       0.988959
#       2             263    16265           5      2212.0       0.990159
# 4     0             267    16265           5        13.0       0.976117
#       1             267    16265           5      2212.0       0.814867
# 6     0             272    16265           5        13.0       0.988281
#       1             272    16265           5      2212.0       1.000000
#       2             272    16265           5      2212.0       0.935273
# 8     0             291    16265           5        13.0       0.936826
#
#                 TrackPID_chiproton  TrackPID_chimuon  TrackPID_chipion  \
# entry subentry
# 0     0                 141.720871          6.895039          6.984430
# 3     0                 208.640289          8.576671         13.129293
#       1                 127.244804          4.662293          6.527868
#       2                   7.874557         47.803963         44.511631
# 4     0                 132.163513          4.724015          4.890599
#       1                  27.751570         15.440325         12.135176
# 6     0                 252.639847         12.249627         20.953836
#       1                   1.765308          3.277233          3.152843
#       2                 167.790527         18.208078         25.685921
# 8     0                 197.807434         12.844907         18.494297
#
#                 TrackLength  num_mc_muon  track_key  key_muon
# entry subentry
# 0     0          272.450762            1          2         2
# 3     0          190.593743            1          6         6
#       1           13.058761            1         15         6
#       2           16.317026            1         14         6
# 4     0          456.941857            1          0         0
#       1            1.961809            1         28         0
# 6     0          115.441180            1          6         6
#       1            3.206996            1         21         6
#       2            1.430780            1         26         6
# 8     0          152.234046            1          9         9

# %%
ev2 = ev.query('TrackPID_chimuon/TrackPID_chiproton<10').groupby(['frunNum','fsubRunNum'])['TrackLength'].max()

# %%
ev2.head()
# Out:
# frunNum  fsubRunNum
# 14117    0             181.388865
#          3             566.431501
#          4             270.905840
#          11             98.477552
#          20            101.202916
# Name: TrackLength, dtype: float64

# %%
ev['proton'] = ev.query('TrackPID_chimuon/TrackPID_chiproton<10').groupby(['frunNum','fsubRunNum'])['TrackLength'].transform(max)

# %%
print ev.query('proton==TrackLength & MCTrackPDG==13').shape[0]
print ev.query('proton==TrackLength').shape[0]
print ev.query('proton==TrackLength & num_mc_muon>0').shape[0]
# Out:
# 63
# 77
# 65

# %%
num_bins = 7
eff_tot = np.zeros((num_bins, num_bins))
for i in range(num_bins):
    for j in range(num_bins):
        cut = 'num_mc_muon>0 & TrackPID_chimuon/TrackPID_chiproton<' + str(0.8-i/num_bins*0.8) + \
        '& TrackPID_chimuon/TrackPID_chipion<'+ str(1.6-j/num_bins*0.8)
        ev['proton'] = ev.query(cut).groupby(['frunNum','fsubRunNum'])['TrackLength'].transform(max)
        eff = ev.query('proton==TrackLength & MCTrackPDG==13').shape[0]/ev.query('proton==TrackLength').shape[0]
        eff2 = ev.query('proton==TrackLength & MCTrackPDG==13').shape[0]/ev.query('num_mc_muon>0').groupby(['frunNum','fsubRunNum'])['TrackLength'].max().shape[0]
        print eff,eff2,i,j
        eff_tot[i,j] = eff*eff2
# Out:
# 0.96 0.96 0 0
# 0.96 0.96 0 1
# 0.96 0.96 0 2
# 0.96 0.96 0 3
# 0.96 0.96 0 4
# 0.973333333333 0.973333333333 0 5
# 0.945945945946 0.933333333333 0 6
# 0.96 0.96 1 0
# 0.96 0.96 1 1
# 0.96 0.96 1 2
# 0.96 0.96 1 3
# 0.96 0.96 1 4
# 0.973333333333 0.973333333333 1 5
# 0.945945945946 0.933333333333 1 6
# 0.973333333333 0.973333333333 2 0
# 0.973333333333 0.973333333333 2 1
# 0.973333333333 0.973333333333 2 2
# 0.973333333333 0.973333333333 2 3
# 0.973333333333 0.973333333333 2 4
# 0.973333333333 0.973333333333 2 5
# 0.945945945946 0.933333333333 2 6
# 0.973333333333 0.973333333333 3 0
# 0.973333333333 0.973333333333 3 1
# 0.973333333333 0.973333333333 3 2
# 0.973333333333 0.973333333333 3 3
# 0.973333333333 0.973333333333 3 4
# 0.973333333333 0.973333333333 3 5
# 0.945945945946 0.933333333333 3 6
# 0.973333333333 0.973333333333 4 0
# 0.973333333333 0.973333333333 4 1
# 0.973333333333 0.973333333333 4 2
# 0.973333333333 0.973333333333 4 3
# 0.973333333333 0.973333333333 4 4
# 0.973333333333 0.973333333333 4 5
# 0.945945945946 0.933333333333 4 6
# 0.973333333333 0.973333333333 5 0
# 0.973333333333 0.973333333333 5 1
# 0.973333333333 0.973333333333 5 2
# 0.973333333333 0.973333333333 5 3
# 0.973333333333 0.973333333333 5 4
# 0.973333333333 0.973333333333 5 5
# 0.945945945946 0.933333333333 5 6
# 0.986666666667 0.986666666667 6 0
# 0.986666666667 0.986666666667 6 1
# 0.986666666667 0.986666666667 6 2
# 0.986666666667 0.986666666667 6 3
# 0.986666666667 0.986666666667 6 4
# 0.986666666667 0.986666666667 6 5
# 0.972972972973 0.96 6 6

# %%
print 'proton then pion'

fig = plt.figure(figsize=(6, 3.2))

ax = fig.add_subplot(111)
ax.set_title('colorMap')
plt.imshow(eff_tot)
ax.set_aspect('equal')

cax = fig.add_axes([0.12, 0.1, 0.78, 0.8])
cax.get_xaxis().set_visible(False)
cax.get_yaxis().set_visible(False)
cax.patch.set_alpha(0)
cax.set_frame_on(False)
plt.colorbar(orientation='vertical')
plt.show() 
#np.amax(passing)

result = np.where(eff_tot == np.amax(eff_tot))
print 'First pion then proton, max value:' , np.max(eff_tot) 
print 'First pion then proton, index:' , eff_tot.argmax()
print('Returned tuple of arrays :', result)
# Out:
# proton then pion
# First pion then proton, max value: 0.9735111111111112
# First pion then proton, index: 42
# ('Returned tuple of arrays :', (array([6, 6, 6, 6, 6, 6]), array([0, 1, 2, 3, 4, 5])))

# %%
dublicates_all = ev[ev.duplicated(['frunNum','fsubRunNum','fEvtNum'],keep=False)]

# %%
ev_sort = ev.sort_values(by=['TrackLength'])

# %%
ev_proton = ev_sort.query('TrackPID_chimuon/TrackPID_chiproton<0.1')

# %%
ev_pion = ev_proton.query('TrackPID_chimuon/TrackPID_chipion<1')

# %%
ev_all = pd.concat([ev_sort,ev_proton,ev_pion])

# %%
dublicates_all = ev[ev.duplicated(['frunNum','fsubRunNum','fEvtNum'],keep='last')]

# %%
dublicates_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 414 entries, (3, 0) to (999, 1)
# Data columns (total 11 columns):
# fEvtNum               414 non-null uint32
# frunNum               414 non-null uint32
# fsubRunNum            414 non-null uint32
# MCTrackPDG            414 non-null float64
# MCTrackPurity         414 non-null float64
# TrackPID_chiproton    414 non-null float64
# TrackPID_chimuon      414 non-null float64
# TrackPID_chipion      414 non-null float64
# TrackLength           414 non-null float64
# num_mc_muon           414 non-null int32
# proton                211 non-null float64
# dtypes: float64(7), int32(1), uint32(3)
# memory usage: 33.7 KB

# %%
ev_sort = ev.query('TrackPID_chimuon>-1 & num_mc_muon>0 & TrackLength>8').sort_values(by=['TrackLength'],ascending=False)
print ev_sort.shape
tot_muons = ev_sort[ev_sort.duplicated(['frunNum','fsubRunNum','fEvtNum'],keep='last')].shape[0]
print tot_muons
eff_ini = ev_sort[ev_sort.duplicated(['fEvtNum','frunNum','fsubRunNum'],keep='last')].query('MCTrackPDG==13').shape[0]/tot_muons
print eff_ini
eff_ini = ev_sort.query('MCTrackPDG==13 & track_key==key_muon').shape[0]/tot_muons
print eff_ini
#tot_muons = ev_sort.query('MCTrackPDG==13').shape[0]
#print tot_muons
# Out:
# (515075, 12)
# 209891
# 0.67464541119
# 1.38550485728

# %%
num_bins = 20
ev_sort = ev.query('TrackPID_chimuon>-1 & num_mc_muon>0 & TrackLength>8').sort_values(by=['TrackLength'],ascending=True)
print ev_sort.shape
eff_tot = np.zeros((num_bins, num_bins))
for i in range(num_bins):
    for j in range(num_bins):
        cut = 'TrackPID_chimuon/TrackPID_chiproton<' + str(0.8-i/num_bins*0.8)
        cut2 ='TrackPID_chimuon/TrackPID_chipion<'+ str(1.2-j/num_bins*0.8)
        ev_proton = ev_sort.query(cut).copy()
        #print ev_proton.shape
        ev_pion = ev_proton.query(cut2).copy()
        #print ev_pion.shape
        ev_all = pd.concat([ev_pion.reset_index(drop=True),ev_proton.reset_index(drop=True),ev_sort.reset_index(drop=True)]).drop_duplicates().reset_index(drop=True)#.drop_duplicates(keep='first').reset_index(drop=True)
        #ev_all = ev_pion.copy()
        #print 'shape ev_all',ev_all.shape
        ##ev_all.append(ev_proton.reset_index(drop=True))
        #print 'shape ev_all',ev_all.shape
        #ev_all.append(ev_sort,ignore_index = True)
        #print 'shape ev_all',ev_all.shape
        #print 'shape ev_all' ,ev_all.shape
        dublicates_all = ev_all[ev_all.duplicated(['fEvtNum','frunNum','fsubRunNum'],keep='last')]
        #dublicates_all.drop_duplicates(['frunNum','fsubRunNum','fEvtNum'],keep='last')
        pur = dublicates_all.query('MCTrackPDG==13').shape[0]/tot_muons
        #print 'shape dublicates_all' ,ev_all[ev_all.duplicated(['frunNum','fsubRunNum','fEvtNum'],keep='last')].shape
        #print 'shape dublicates_all' ,ev_all[ev_all.duplicated(['frunNum','fsubRunNum','fEvtNum'],keep=False)].shape
        eff = dublicates_all.shape[0]/tot_muons
        #eff2 = ev.query('proton==TrackLength & MCTrackPDG==13').shape[0]/ev.query('num_mc_muon>0').groupby(['frunNum','fsubRunNum'])['TrackLength'].max().shape[0]
        print pur,i,j
        eff_tot[i,j] = pur
# Out:
# (515075, 12)
# 0.55887103306 0 0
# 0.567537436098 0 1
# 0.578890948159 0 2
# 0.591297387692 0 3
# 0.602674721641 0 4
# 0.613051536274 0 5
# 0.620703126861 0 6
# 0.626463259501 0 7
# 0.6306940269 0 8
# 0.633185796437 0 9
# 0.634191080132 0 10
# 0.632714123045 0 11
# 0.626334621303 0 12
# 0.612856196788 0 13
# 0.590439799706 0 14
# 0.566446393604 0 15
# 0.552867917157 0 16
# 0.548046366924 0 17
# 0.54647888666 0 18
# 0.545749936872 0 19
# 0.560729140363 1 0
# 0.569104916361 1 1
# 0.580067749451 1 2
# 0.591954871814 1 3
# 0.603032049969 1 4
# 0.613237347004 1 5
# 0.620879408836 1 6
# 0.62667289212 1 7
# 0.630922717029 1 8
# 0.633466894722 1 9
# 0.634586523481 1 10
# 0.633281083991 1 11
# 0.627177916156 1 12
# 0.613990118681 1 13
# 0.591992986836 1 14
# 0.568342615929 1 15
# 0.554949950212 1 16
# 0.550190336889 1 17
# 0.548622856626 1 18
# 0.547898671215 1 19
# 0.562768294019 2 0
# 0.570805799201 2 1
# 0.581277901387 2 2
# 0.592621884693 2 3
# 0.603384613919 2 4
# 0.613413628979 2 5
# 0.621050926433 2 6
# 0.626915875383 2 7
# 0.631194286558 2 8
# 0.633828987427 2 9
# 0.635029610607 2 10
# 0.633886159959 2 11
# 0.628097441053 2 12
# 0.615305086926 2 13
# 0.593689105298 2 14
# 0.57043417774 2 15
# 0.55727496653 2 16
# 0.552548703851 2 17
# 0.550995516721 2 18
# 0.550276095688 2 19
# 0.564583521923 3 0
# 0.572316106932 3 1
# 0.58241182328 3 2
# 0.593274604438 3 3
# 0.603703827225 3 4
# 0.613566089065 3 5
# 0.621179564631 3 6
# 0.627073099847 3 7
# 0.63141821231 3 8
# 0.634100556956 3 9
# 0.635363117046 3 10
# 0.634362597729 3 11
# 0.628854977107 3 12
# 0.61635325002 3 13
# 0.595185119896 3 14
# 0.57227799191 3 15
# 0.559276005165 3 16
# 0.554625972529 3 17
# 0.553091842909 3 18
# 0.552386715009 3 19
# 0.566675083734 4 0
# 0.574131334836 4 1
# 0.583798257191 4 2
# 0.594089313024 4 3
# 0.604142149973 4 4
# 0.61380430795 4 5
# 0.621317731584 4 6
# 0.627239853067 4 7
# 0.631656431195 4 8
# 0.63444359215 4 9
# 0.635820497306 4 10
# 0.635039139363 4 11
# 0.629779266381 4 12
# 0.617677747021 4 13
# 0.596990819044 4 14
# 0.574469605652 4 15
# 0.561634372126 4 16
# 0.557031983268 4 17
# 0.555512146781 4 18
# 0.554811783259 4 19
# 0.568952456275 5 0
# 0.576032321538 5 1
# 0.5852704499 5 2
# 0.594942136633 5 3
# 0.604580472722 5 4
# 0.614037762458 5 5
# 0.621489249182 5 6
# 0.627468543196 5 7
# 0.631947058235 5 8
# 0.634834271122 5 9
# 0.636354107608 5 10
# 0.635777617906 5 11
# 0.630784550076 5 12
# 0.619145175353 5 13
# 0.59896803579 5 14
# 0.576770800082 5 15
# 0.564102319776 5 16
# 0.559580925337 5 17
# 0.558075381984 5 18
# 0.557384547217 5 19
# 0.571196478172 6 0
# 0.577895193219 6 1
# 0.586599711279 6 2
# 0.595737787709 6 3
# 0.605014031092 6 4
# 0.614266452587 6 5
# 0.621698881801 6 6
# 0.627697233326 6 7
# 0.632266271541 6 8
# 0.63527259387 6 9
# 0.636925832932 6 10
# 0.636506567695 6 11
# 0.631813655659 6 12
# 0.620612603685 6 13
# 0.600926195025 6 14
# 0.579100580778 6 15
# 0.566679848112 6 16
# 0.562201333073 6 17
# 0.560724375986 6 18
# 0.560047834352 6 19
# 0.573616782044 7 0
# 0.579953404386 7 1
# 0.588138605276 7 2
# 0.596790715181 7 3
# 0.605523819506 7 4
# 0.61450943585 7 5
# 0.621851341887 7 6
# 0.627897337189 7 7
# 0.632514019181 7 8
# 0.635653744086 7 9
# 0.637445150102 7 10
# 0.637225988727 7 11
# 0.632842761243 7 12
# 0.62205144575 7 13
# 0.602931998037 7 14
# 0.581630465337 7 15
# 0.569424129667 7 16
# 0.565036137805 7 17
# 0.563578238228 7 18
# 0.562906460973 7 19
# 0.575856039563 8 0
# 0.581882977355 8 1
# 0.589634619874 8 2
# 0.597838878275 8 3

# %%
ev_all.head(3)

# %%
dublicates_all.tail(10)

# %%
print 'proton then pion'

fig = plt.figure(figsize=(6, 3.2))

ax = fig.add_subplot(111)
ax.set_title('colorMap')
plt.imshow(eff_tot)
ax.set_aspect('equal')

cax = fig.add_axes([0.12, 0.1, 0.78, 0.8])
cax.get_xaxis().set_visible(False)
cax.get_yaxis().set_visible(False)
cax.patch.set_alpha(0)
cax.set_frame_on(False)
plt.colorbar(orientation='vertical')
plt.show() 
#np.amax(passing)

result = np.where(eff_tot == np.amax(eff_tot))
print 'First pion then proton, max value:' , np.max(eff_tot) 
print 'First pion then proton, index:' , eff_tot.argmax()
print('Returned tuple of arrays :', result)
